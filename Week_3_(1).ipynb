# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishaanbest25/CoinMarketCap/blob/main/Week_3_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-958d491c-8f10-48b6-8d7d-2b693e46f414" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-958d491c-8f10-48b6-8d7d-2b693e46f414">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Data-cleaning-for-beginners-using-pandas.csv")
data
# Out:
#     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
data.isnull().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Index', 'Age', 'Salary', 'Rating', 'Location', 'Established',
#        'Easy Apply'],
#       dtype='object')

# %%
avg_age = data['Age'].median()
avg_age
# Out:
# 39.5

# %%
data['Age'] = data.Age.fillna(avg_age)
data['Age'] = data.Age.round(decimals=0).astype(int)
data.head(2)
# Out:
#    Index  Age     Salary  Rating     Location  Established Easy Apply
# 0      0   44  $44k-$99k     5.4     India,In         1999       TRUE
# 1      1   66  $55k-$66k     3.5  New York,Ny         2002       TRUE

# %%
data['Salary'] = data.Salary.str.replace("$","")
data['Salary'] = data.Salary.str.replace("k","000")
data.head(1)
# Out:
# <ipython-input-11-96a1eec967cb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Salary'] = data.Salary.str.replace("$","")
#    Index  Age       Salary  Rating  Location  Established Easy Apply
# 0      0   44  44000-99000     5.4  India,In         1999       TRUE

# %%
data['Location'] = data['Location'].str.split(',').str[0]
data['Location'] = data['Location'].str.replace(" Aus","")
data['Location'] = data['Location'].str.replace(" In","")
data.head(2)
# Out:
#    Index  Age       Salary  Rating  Location  Established Easy Apply
# 0      0   44  44000-99000     5.4     India         1999       TRUE
# 1      1   66  55000-66000     3.5  New York         2002       TRUE

# %%
data['Easy Apply'] = data['Easy Apply'].str.replace("-1","FALSE")
data.head(2)
# Out:
#    Index  Age       Salary  Rating  Location  Established Easy Apply
# 0      0   44  44000-99000     5.4     India         1999       TRUE
# 1      1   66  55000-66000     3.5  New York         2002       TRUE

# %%
data.loc[data['Rating'] <= 0, 'Rating'] = np.nan

avg_rate = data['Rating'].median()
avg_rate
# Out:
# 5.3

# %%
data['Rating'] = data['Rating'].fillna(avg_rate)
data['Rating'] = data['Rating'].round(decimals=1)
data.head(2)
# Out:
#    Index  Age       Salary  Rating  Location  Established Easy Apply
# 0      0   44  44000-99000     5.4     India         1999       TRUE
# 1      1   66  55000-66000     3.5  New York         2002       TRUE

# %%
data.loc[data['Established'] <= 0,'Established'] = np.nan

avg_yr = data['Established'].median()
avg_yr
# Out:
# 1988.0

# %%
data['Established'] = data['Established'].fillna(avg_yr)
data['Established'] = data['Established'].astype(int)
data.head(2)
# Out:
#    Index  Age       Salary  Rating  Location  Established Easy Apply
# 0      0   44  44000-99000     5.4     India         1999       TRUE
# 1      1   66  55000-66000     3.5  New York         2002       TRUE

# %%
data.isnull().sum()
# Out:
# Index          0
# Age            0
# Salary         0
# Rating         0
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %% [markdown]
# ***FINAL DATA TABLE :***

# %%
data
# Out:
#     Index  Age        Salary  Rating   Location  Established Easy Apply
# 0       0   44   44000-99000     5.4      India         1999       TRUE
# 1       1   66   55000-66000     3.5   New York         2002       TRUE
# 2       2   40   77000-89000     5.3   New York         1988      FALSE
# 3       3   64   44000-99000     4.4      India         1988      FALSE
# 4       4   25   44000-99000     6.4  Australia         2002      FALSE
# 5       5   44   77000-89000     1.4      India         1999       TRUE
# 6       6   21   44000-99000     5.3   New York         1988      FALSE
# 7       7   44   44000-99000     5.3  Australia         1988      FALSE
# 8       8   35   44000-99000     5.4   New York         1988      FALSE
# 9       9   22   44000-99000     7.7      India         1988       TRUE
# 10     10   55   10000-49000     5.4      India         2008       TRUE
# 11     11   44   10000-49000     6.7      India         2009      FALSE
# ...
